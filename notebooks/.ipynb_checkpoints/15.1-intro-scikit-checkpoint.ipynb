# %% [markdown]
# # Machine Learning

# %%
#imports
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn import datasets
from sklearn.decomposition import PCA

# %%
#load the data
iris = datasets.load_iris()

iris.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
#inspect the data
iris["data"].shape #150 rows and 4 columns in the data key (a raw numpy matrix)
iris["target_names"] #target gives entries for each group (species)
iris["feature_names"]
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
#clean the data
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')  #if there is any missing value, fill it in with the mean
imputed_data = imputer.fit_transform(iris.data)
#imputed_data = imputer.fit(iris.data).transform(iris.data)

# %%
#visualize the raw data
plt.scatter(iris.data[:, 0], iris.data[:, 1], c=data.target) #must be "c", not "color", but idk why...
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
# Out:
# Text(0, 0.5, 'Sepal Width')

# %%
#PCA for dimension reduction
from sklearn.decomposition import PCA

pca = PCA(n_components=3) #retain only the first three PCs
X_r = pca.fit_transform(iris.data)

# %%
## Percentage of variance explained for each component
print(f"Explained variance ratio (first three components): {pca.explained_variance_ratio_}")
# Out:
# Explained variance ratio (first two components): [0.92461872 0.05306648 0.01710261]

# %%
#Visualizing the PCs
colors = ["plum", "cornflowerblue", "orange"]

for color, i, target_name in zip(colors, [0, 1, 2], iris.target_names):
    plt.scatter(X_r[iris.target == i, 0], X_r[iris.target == i, 1], color=color, label=target_name)

plt.legend()
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PC2 vs. PC1 for iris data");

# %%
#Visualizing the PCs
colors = ["plum", "cornflowerblue", "orange"]

for color, i, target_name in zip(colors, [0, 1, 2], iris.target_names):
    plt.scatter(X_r[iris.target == i, 1], X_r[iris.target == i, 2], color=color, label=target_name)

plt.legend()
plt.xlabel("PC2")
plt.ylabel("PC3")
plt.title("PC3 vs. PC2 for iris data");

# %%
#Visualizing the PCs
colors = ["plum", "cornflowerblue", "orange"]

for color, i, target_name in zip(colors, [0, 1, 2], iris.target_names):
    plt.scatter(X_r[iris.target == i, 0], X_r[iris.target == i, 2], color=color, label=target_name)

plt.legend()
plt.xlabel("PC1")
plt.ylabel("PC3")
plt.title("PC3 vs. PC1 for iris data");
